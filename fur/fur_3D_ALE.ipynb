# %%
import pandas as pd

# %%
var_df = pd.read_csv('fur_ale_muts.csv')
var_df.fillna('', inplace=True)
var_df
# Out:
#     AA pos mutation type             mutation effect mutation source  \
# 0        7           SUB  nonsynonymous substitution     unpublished
# 1       14           SUB  nonsynonymous substitution     unpublished
# 2       14           SUB  nonsynonymous substitution     unpublished
# 3       18           SUB  nonsynonymous substitution        paraquat
# 4       18           SUB  nonsynonymous substitution     unpublished
# 5       23           SUB  nonsynonymous substitution     unpublished
# 6       42           SUB  nonsynonymous substitution        paraquat
# 7       42           SUB  nonsynonymous substitution     unpublished
# 8       53           SUB  nonsynonymous substitution        paraquat
# 9       61           SUB  nonsynonymous substitution     unpublished
# 10      70           SUB  nonsynonymous substitution     unpublished
# 11      71           SUB  nonsynonymous substitution        paraquat
# 12      73           SUB  nonsynonymous substitution     unpublished
# 13      92           SUB  nonsynonymous substitution     unpublished
# 14     102           SUB  nonsynonymous substitution     unpublished
# 15     104           SUB  nonsynonymous substitution     unpublished
# 16     128           SUB  nonsynonymous substitution     unpublished
# 17     131           SUB  nonsynonymous substitution     unpublished
#
#    AA ref seq AA seq change  mutation count mutation effect color  \
# 0           A             P               1               #DD8452
# 1           K             N               1               #DD8452
# 2           K             Q               1               #DD8452
# 3           P             T               3               #DD8452
# 4           P             T               1               #DD8452
# 5           L             Q               2               #DD8452
# 6           R             H               1               #DD8452
# 7           R             H               1               #DD8452
# 8           A             G               1               #DD8452
# 9           Q             E               1               #DD8452
# 10          R             S              13               #DD8452
# 11          H             Y               1               #DD8452
# 12          F             I               1               #DD8452
# 13          I             N               1               #DD8452
# 14          F             L               1               #DD8452
# 15          D             V               1               #DD8452
# 16          Y             F               1               #DD8452
# 17          G             A               1               #DD8452
#
#    selection pressure color       name
# 0                   #AD8BC9    SUB A7P
# 1                   #AD8BC9   SUB K14N
# 2                   #AD8BC9   SUB K14Q
# 3                   #6DCCDA   SUB P18T
# 4                   #AD8BC9   SUB P18T
# 5                   #AD8BC9   SUB L23Q
# 6                   #6DCCDA   SUB R42H
# 7                   #AD8BC9   SUB R42H
# 8                   #6DCCDA   SUB A53G
# 9                   #AD8BC9   SUB Q61E
# 10                  #AD8BC9   SUB R70S
# 11                  #6DCCDA   SUB H71Y
# 12                  #AD8BC9   SUB F73I
# 13                  #AD8BC9   SUB I92N
# 14                  #AD8BC9  SUB F102L
# 15                  #AD8BC9  SUB D104V
# 16                  #AD8BC9  SUB Y128F
# 17                  #AD8BC9  SUB G131A

# %%
import warnings
warnings.filterwarnings('ignore')


out_df = pd.DataFrame(columns=['AA position', 'mutation count', 'color'])
for g, gdf in var_df.groupby(['AA pos', 'mutation effect color']):
    out_df = out_df.append({
        'AA position': g[0],
        'color': g[1],
        'mutation count': gdf['mutation count'].sum()
    }, ignore_index=True)
out_df
# Out:
#    AA position mutation count    color
# 0            7              1  #DD8452
# 1           14              2  #DD8452
# 2           18              4  #DD8452
# 3           23              2  #DD8452
# 4           42              2  #DD8452
# 5           53              1  #DD8452
# 6           61              1  #DD8452
# 7           70             13  #DD8452
# 8           71              1  #DD8452
# 9           73              1  #DD8452
# 10          92              1  #DD8452
# 11         102              1  #DD8452
# 12         104              1  #DD8452
# 13         128              1  #DD8452
# 14         131              1  #DD8452

# %%
# the structure for Fur currently being used includes the start Methionine,
# therefore variant residue position is the same as the AA position.
out_df['residue pos'] = out_df['AA position']
out_df.head()
# Out:
#   AA position mutation count    color residue pos
# 0           7              1  #DD8452           7
# 1          14              2  #DD8452          14
# 2          18              4  #DD8452          18
# 3          23              2  #DD8452          23
# 4          42              2  #DD8452          42

# %%
with open('vars.json', 'w') as outfile:  # for NGL
    outfile.write(out_df.to_json())
