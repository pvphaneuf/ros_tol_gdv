# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
all_mut_df = pd.read_pickle('../aledb_obs_mut_genes_of_interest_df.pkl')
all_mut_df.head()
# Out:
#                              exp     sample  Position Mutation Type  \
# 466615           10mM_Lactose_R1   8 47 1 1   4159160           SNP
# 303555           10mM_Lactose_R2  9 104 1 2   4158805           SNP
# 303558           10mM_Lactose_R2   9 46 1 2   4159070           SNP
# 366871           10mM_Lactose_R3   10 6 1 3   4159121           SNP
# 353677  1mM_Gluc_10mM_Lactose_R1   4 49 1 1   4159087           SNP
#
#        Sequence Change          Details  Gene ALEdb source  genetic  \
# 466615             T→A  L224Q (CTG→CAG)  oxyR      private     True
# 303555             C→A  L106I (CTA→ATA)  oxyR      private     True
# 303558             T→A  L194Q (CTG→CAG)  oxyR      private     True
# 366871             C→A  A211D (GCC→GAC)  oxyR      private     True
# 353677             T→G  L200V (TTG→GTG)  oxyR      private     True
#
#        clean genes    bnums genes of interest
# 466615      {oxyR}  {b3961}           {b3961}
# 303555      {oxyR}  {b3961}           {b3961}
# 303558      {oxyR}  {b3961}           {b3961}
# 366871      {oxyR}  {b3961}           {b3961}
# 353677      {oxyR}  {b3961}           {b3961}

# %%
BNUM_OF_INTEREST = 'b2898'

all_mut_df['gene of interest'] = all_mut_df['genes of interest'].apply(lambda s: True if BNUM_OF_INTEREST in s else False )
fur_mut_df = all_mut_df[all_mut_df['gene of interest']].drop(columns=['gene of interest'])
fur_mut_df
# Out:
#                                                       exp     sample  \
# 468518  GLU_16321-M9-NC_000913_3gb-stationary-37-Gluco...  11 20 0 1
# 468601  GLU_16321-M9-NC_000913_3gb-stationary-37-Gluco...  13 25 0 1
# 468720  GLU_16321-M9-NC_000913_3gb-stationary-37-Gluco...  17 23 0 1
# 468758  GLU_16321-M9-NC_000913_3gb-stationary-37-Gluco...  19 21 0 1
# 158708  GLU_18361-M9-NC_000913_3gb-stationary-37-Gluco...  21 21 0 1
# 158809  GLU_18361-M9-NC_000913_3gb-stationary-37-Gluco...  23 22 0 1
# 158887  GLU_18361-M9-NC_000913_3gb-stationary-37-Gluco...  25 17 0 1
# 158959  GLU_18361-M9-NC_000913_3gb-stationary-37-Gluco...  27 74 0 1
# 159028  GLU_18361-M9-NC_000913_3gb-stationary-37-Gluco...  29 18 0 1
# 445554  GLU_4721-M9-NC_000913_3gb-stationary-37-Glucos...   1 17 0 1
# 445601  GLU_4721-M9-NC_000913_3gb-stationary-37-Glucos...   3 34 0 1
# 445707  GLU_4721-M9-NC_000913_3gb-stationary-37-Glucos...   5 20 0 1
# 445832  GLU_4721-M9-NC_000913_3gb-stationary-37-Glucos...   7 29 0 1
# 445879  GLU_4721-M9-NC_000913_3gb-stationary-37-Glucos...   9 31 0 1
# 159621  GLU_ALE4-M9-NC_000913_3gb-stationary-37-Glucos...  14 21 0 1
# 159668  GLU_ALE4-M9-NC_000913_3gb-stationary-37-Glucos...  16 28 1 1
# 159706  GLU_ALE4-M9-NC_000913_3gb-stationary-37-Glucos...  18 24 1 1
# 159725  GLU_ALE4-M9-NC_000913_3gb-stationary-37-Glucos...  18 36 1 1
# 159693  GLU_ALE4-M9-NC_000913_3gb-stationary-37-Glucos...  18 11 1 1
# 363696                          MG1655-delta-mutY_nor_875  12 30 1 1
# 445261  MUSE-M9-NC_000913_3gb-stationary-37-Glucose2-N...  33 61 0 1
# 445329  MUSE-M9-NC_000913_3gb-stationary-37-Glucose2-N...  35 27 0 1
# 445415  MUSE-M9-NC_000913_3gb-stationary-37-Glucose2-N...  37 57 0 1
# 445406  MUSE-M9-NC_000913_3gb-stationary-37-Glucose2-N...  37 25 1 1
# 130506                                      OxidizeME_PQ3  18 36 1 1
# 131765                                           ROS_eAMP   1 17 0 1
# 132732                                           ROS_eAMP   3 34 0 1
# 132842                                           ROS_eAMP   5 20 0 1
# 132961                                           ROS_eAMP   7 29 0 1
# 133011                                           ROS_eAMP   9 31 0 1
# 131816                                           ROS_eAMP  11 20 0 1
# 131916                                           ROS_eAMP  13 25 0 1
# 132024                                           ROS_eAMP  14 21 0 1
# 132080                                           ROS_eAMP  16 28 1 1
# 132147                                           ROS_eAMP  17 23 0 1
# 132203                                           ROS_eAMP  18 24 1 1
# 132232                                           ROS_eAMP  18 36 1 1
# 132184                                           ROS_eAMP  18 11 1 1
# 132250                                           ROS_eAMP  19 21 0 1
# 132332                                           ROS_eAMP  21 21 0 1
# 132436                                           ROS_eAMP  23 22 0 1
# 132522                                           ROS_eAMP  25 17 0 1
# 132604                                           ROS_eAMP  27 74 0 1
# 132672                                           ROS_eAMP  29 18 0 1
# 424994  rpoB_E672K-M9-NC_000913_3gb-stationary-37-Gluc...   8 17 1 1
# 424959  rpoB_E672K-M9-NC_000913_3gb-stationary-37-Gluc...  12 15 0 1
#
#         Position Mutation Type Sequence Change          Details  Gene  \
# 468518   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 468601   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 468720   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 468758   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 158708   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 158809   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 158887   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 158959   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 159028   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 445554   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 445601   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 445707   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 445832   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 445879   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 159621   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 159668   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 159706   3041393           SNP             G→T   W27C (TGG→TGT)  ygfZ
# 159725   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 159693   3041973           SNP             G→C  G221R (GGT→CGT)  ygfZ
# 363696   3041495           SNP             C→A   A61A (GCC→GCA)  ygfZ
# 445261   3042064           SNP             T→A  L251Q (CTG→CAG)  ygfZ
# 445329   3041974           SNP             G→T  G221V (GGT→GTT)  ygfZ
# 445415   3041667           SNP             G→T  G119C (GGT→TGT)  ygfZ
# 445406   3041997           SNP             T→C  Y229H (TAT→CAT)  ygfZ
# 130506   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 131765   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 132732   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 132842   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 132961   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 133011   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 131816   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 131916   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 132024   3041398           SNP             T→G   L29R (CTT→CGT)  ygfZ
# 132080   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 132147   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 132203   3041393           SNP             G→T   W27C (TGG→TGT)  ygfZ
# 132232   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 132184   3041973           SNP             G→C  G221R (GGT→CGT)  ygfZ
# 132250   3041632           SNP             T→A  V107E (GTG→GAG)  ygfZ
# 132332   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 132436   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 132522   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 132604   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 132672   3041634           SNP             A→C  T108P (ACC→CCC)  ygfZ
# 424994   3041902           SNP             G→A  G197D (GGT→GAT)  ygfZ
# 424959   3041449           SNP             C→T   T46I (ACA→ATA)  ygfZ
#
#        ALEdb source  genetic clean genes    bnums genes of interest
# 468518      private     True      {ygfZ}  {b2898}           {b2898}
# 468601      private     True      {ygfZ}  {b2898}           {b2898}
# 468720      private     True      {ygfZ}  {b2898}           {b2898}
# 468758      private     True      {ygfZ}  {b2898}           {b2898}
# 158708      private     True      {ygfZ}  {b2898}           {b2898}
# 158809      private     True      {ygfZ}  {b2898}           {b2898}
# 158887      private     True      {ygfZ}  {b2898}           {b2898}
# 158959      private     True      {ygfZ}  {b2898}           {b2898}
# 159028      private     True      {ygfZ}  {b2898}           {b2898}
# 445554      private     True      {ygfZ}  {b2898}           {b2898}
# 445601      private     True      {ygfZ}  {b2898}           {b2898}
# 445707      private     True      {ygfZ}  {b2898}           {b2898}
# 445832      private     True      {ygfZ}  {b2898}           {b2898}
# 445879      private     True      {ygfZ}  {b2898}           {b2898}
# 159621      private     True      {ygfZ}  {b2898}           {b2898}
# 159668      private     True      {ygfZ}  {b2898}           {b2898}
# 159706      private     True      {ygfZ}  {b2898}           {b2898}
# 159725      private     True      {ygfZ}  {b2898}           {b2898}
# 159693      private     True      {ygfZ}  {b2898}           {b2898}
# 363696      private     True      {ygfZ}  {b2898}           {b2898}
# 445261      private     True      {ygfZ}  {b2898}           {b2898}
# 445329      private     True      {ygfZ}  {b2898}           {b2898}
# 445415      private     True      {ygfZ}  {b2898}           {b2898}
# 445406      private     True      {ygfZ}  {b2898}           {b2898}
# 130506       public     True      {ygfZ}  {b2898}           {b2898}
# 131765       public     True      {ygfZ}  {b2898}           {b2898}
# 132732       public     True      {ygfZ}  {b2898}           {b2898}
# 132842       public     True      {ygfZ}  {b2898}           {b2898}
# 132961       public     True      {ygfZ}  {b2898}           {b2898}
# 133011       public     True      {ygfZ}  {b2898}           {b2898}
# 131816       public     True      {ygfZ}  {b2898}           {b2898}
# 131916       public     True      {ygfZ}  {b2898}           {b2898}
# 132024       public     True      {ygfZ}  {b2898}           {b2898}
# 132080       public     True      {ygfZ}  {b2898}           {b2898}
# 132147       public     True      {ygfZ}  {b2898}           {b2898}
# 132203       public     True      {ygfZ}  {b2898}           {b2898}
# 132232       public     True      {ygfZ}  {b2898}           {b2898}
# 132184       public     True      {ygfZ}  {b2898}           {b2898}
# 132250       public     True      {ygfZ}  {b2898}           {b2898}
# 132332       public     True      {ygfZ}  {b2898}           {b2898}
# 132436       public     True      {ygfZ}  {b2898}           {b2898}
# 132522       public     True      {ygfZ}  {b2898}           {b2898}
# 132604       public     True      {ygfZ}  {b2898}           {b2898}
# 132672       public     True      {ygfZ}  {b2898}           {b2898}
# 424994      private     True      {ygfZ}  {b2898}           {b2898}
# 424959      private     True      {ygfZ}  {b2898}           {b2898}

# %%
fur_mut_df.to_pickle('./targ_mut_df.pkl')
