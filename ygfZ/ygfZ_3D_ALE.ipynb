# %%
import pandas as pd

# %%
var_df = pd.read_csv('ygfZ_ale_muts.csv')
var_df.fillna('', inplace=True)
var_df
# Out:
#     AA pos mutation type             mutation effect mutation source  \
# 0       27           SUB  nonsynonymous substitution        paraquat
# 1       27           SUB  nonsynonymous substitution     unpublished
# 2       29           SUB  nonsynonymous substitution        paraquat
# 3       29           SUB  nonsynonymous substitution     unpublished
# 4       46           SUB  nonsynonymous substitution     unpublished
# 5       61           SUB     synonymous substitution     unpublished
# 6      107           SUB  nonsynonymous substitution        paraquat
# 7      107           SUB  nonsynonymous substitution     unpublished
# 8      108           SUB  nonsynonymous substitution        paraquat
# 9      108           SUB  nonsynonymous substitution     unpublished
# 10     119           SUB  nonsynonymous substitution     unpublished
# 11     197           SUB  nonsynonymous substitution     unpublished
# 12     221           SUB  nonsynonymous substitution        paraquat
# 13     221           SUB  nonsynonymous substitution     unpublished
# 14     221           SUB  nonsynonymous substitution     unpublished
# 15     229           SUB  nonsynonymous substitution     unpublished
# 16     251           SUB  nonsynonymous substitution     unpublished
#
#    AA ref seq AA seq change  mutation count mutation effect color  \
# 0           W             C               1               #DD8452
# 1           W             C               1               #DD8452
# 2           L             R               6               #DD8452
# 3           L             R               1               #DD8452
# 4           T             I               1               #DD8452
# 5           A             A               1               #55A868
# 6           V             E               5               #DD8452
# 7           V             E               1               #DD8452
# 8           T             P               6               #DD8452
# 9           T             P               1               #DD8452
# 10          G             C               1               #DD8452
# 11          G             D               1               #DD8452
# 12          G             R               1               #DD8452
# 13          G             R               1               #DD8452
# 14          G             V               1               #DD8452
# 15          Y             H               1               #DD8452
# 16          L             Q               1               #DD8452
#
#    selection pressure color       name
# 0                   #6DCCDA   SUB W27C
# 1                   #AD8BC9   SUB W27C
# 2                   #6DCCDA   SUB L29R
# 3                   #AD8BC9   SUB L29R
# 4                   #AD8BC9   SUB T46I
# 5                   #AD8BC9   SUB A61A
# 6                   #6DCCDA  SUB V107E
# 7                   #AD8BC9  SUB V107E
# 8                   #6DCCDA  SUB T108P
# 9                   #AD8BC9  SUB T108P
# 10                  #AD8BC9  SUB G119C
# 11                  #AD8BC9  SUB G197D
# 12                  #6DCCDA  SUB G221R
# 13                  #AD8BC9  SUB G221R
# 14                  #AD8BC9  SUB G221V
# 15                  #AD8BC9  SUB Y229H
# 16                  #AD8BC9  SUB L251Q

# %%
import warnings
warnings.filterwarnings('ignore')


out_df = pd.DataFrame(columns=['AA position', 'mutation count', 'color'])
for g, gdf in var_df.groupby(['AA pos', 'mutation effect color']):
    out_df = out_df.append({
        # display(g, gdf, )
        'AA position': g[0],
        'color': g[1],
        'mutation count': gdf['mutation count'].sum()
    }, ignore_index=True)
out_df
# Out:
#    AA position mutation count    color
# 0           27              2  #DD8452
# 1           29              7  #DD8452
# 2           46              1  #DD8452
# 3           61              1  #55A868
# 4          107              6  #DD8452
# 5          108              7  #DD8452
# 6          119              1  #DD8452
# 7          197              1  #DD8452
# 8          221              3  #DD8452
# 9          229              1  #DD8452
# 10         251              1  #DD8452

# %%
# the structure for IscR currently being used includes the start Methionine,
# therefore variant residue position is the same as the AA position.
out_df['residue pos'] = out_df['AA position']
out_df.head()
# Out:
#   AA position mutation count    color residue pos
# 0          27              2  #DD8452          27
# 1          29              7  #DD8452          29
# 2          46              1  #DD8452          46
# 3          61              1  #55A868          61
# 4         107              6  #DD8452         107

# %%
with open('vars.json', 'w') as outfile:  # for NGL
    outfile.write(out_df.to_json())
